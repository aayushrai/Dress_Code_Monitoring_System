# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import Adam
import keras,os
import numpy as np
import matplotlib.pyplot as plt

# %%
h = 300
w = 150
    
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=( h, w,1)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# model.add(Conv2D(64, (3, 3)))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.2))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('tanh'))
model.add(Dropout(0.3))
model.add(Dense(2,activation='softmax'))

# model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])


# opt = Adam(lr=0.005)
model.compile(optimizer="adam", loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
batch_size = 10

train_datagen = ImageDataGenerator(horizontal_flip=True,brightness_range=[0.3,1.0],width_shift_range=[-10,10],height_shift_range=[0,20])
test_datagen = ImageDataGenerator(horizontal_flip=True,brightness_range=[0.3,1.0],width_shift_range=[-10,10],height_shift_range=[0,20])


train_generator = train_datagen.flow_from_directory('croped/train', target_size=(h, w),batch_size=batch_size,color_mode="grayscale") 
validation_generator = test_datagen.flow_from_directory('croped/test',target_size=(h, w),batch_size=batch_size,color_mode="grayscale")

print(train_generator.samples)
print(validation_generator.samples)
print(train_generator.class_indices)
# Out:
# Found 1182 images belonging to 2 classes.
# Found 389 images belonging to 2 classes.
# 1182
# 389
# {'formal': 0, 'informal': 1}

# %%
history = model.fit_generator(
        train_generator,
        steps_per_epoch=train_generator.samples // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // batch_size)


model.save('models/version4.h5')  # always save your weights after training or during trainin
# Out:
# /home/uchiha/ObjectDetectionEnv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 118/118 [==============================] - 38s 319ms/step - loss: 3.3931 - accuracy: 0.5139 - val_loss: 0.6947 - val_accuracy: 0.5053
# Epoch 2/50
# 118/118 [==============================] - 38s 318ms/step - loss: 0.7590 - accuracy: 0.5446 - val_loss: 0.6947 - val_accuracy: 0.5079
# Epoch 3/50
# 118/118 [==============================] - 38s 321ms/step - loss: 0.7361 - accuracy: 0.5404 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 4/50
# 118/118 [==============================] - 38s 321ms/step - loss: 0.7071 - accuracy: 0.5274 - val_loss: 0.6967 - val_accuracy: 0.4947
# Epoch 5/50
# 118/118 [==============================] - 39s 327ms/step - loss: 0.7635 - accuracy: 0.4792 - val_loss: 0.7012 - val_accuracy: 0.4974
# Epoch 6/50
# 118/118 [==============================] - 38s 324ms/step - loss: 0.7304 - accuracy: 0.4873 - val_loss: 0.6947 - val_accuracy: 0.5053
# Epoch 7/50
# 118/118 [==============================] - 39s 329ms/step - loss: 0.7101 - accuracy: 0.5284 - val_loss: 0.6940 - val_accuracy: 0.4947
# Epoch 8/50
# 118/118 [==============================] - 39s 329ms/step - loss: 0.7100 - accuracy: 0.5490 - val_loss: 0.6940 - val_accuracy: 0.5000
# Epoch 9/50
# 118/118 [==============================] - 39s 332ms/step - loss: 0.7122 - accuracy: 0.5114 - val_loss: 0.7008 - val_accuracy: 0.4921
# Epoch 10/50
# 118/118 [==============================] - 39s 331ms/step - loss: 0.7142 - accuracy: 0.4990 - val_loss: 0.7084 - val_accuracy: 0.4947
# Epoch 11/50
# 118/118 [==============================] - 39s 330ms/step - loss: 0.7178 - accuracy: 0.4910 - val_loss: 0.6995 - val_accuracy: 0.4947
# Epoch 12/50
# 118/118 [==============================] - 39s 333ms/step - loss: 0.7108 - accuracy: 0.5108 - val_loss: 0.7195 - val_accuracy: 0.5053
# Epoch 13/50
# 118/118 [==============================] - 39s 329ms/step - loss: 0.6934 - accuracy: 0.5594 - val_loss: 0.7066 - val_accuracy: 0.5079
# Epoch 14/50
# 118/118 [==============================] - 39s 330ms/step - loss: 0.6911 - accuracy: 0.5556 - val_loss: 0.7055 - val_accuracy: 0.5026
# Epoch 15/50
# 118/118 [==============================] - 39s 330ms/step - loss: 0.7055 - accuracy: 0.4998 - val_loss: 0.7114 - val_accuracy: 0.5000
# Epoch 16/50
# 118/118 [==============================] - 39s 327ms/step - loss: 0.6943 - accuracy: 0.5278 - val_loss: 0.7024 - val_accuracy: 0.4974
# Epoch 17/50
# 118/118 [==============================] - 39s 330ms/step - loss: 0.6921 - accuracy: 0.5522 - val_loss: 0.7036 - val_accuracy: 0.5026
# Epoch 18/50
# 118/118 [==============================] - 39s 327ms/step - loss: 0.7034 - accuracy: 0.5280 - val_loss: 0.6933 - val_accuracy: 0.4974
# Epoch 19/50
# 118/118 [==============================] - 39s 333ms/step - loss: 0.6953 - accuracy: 0.5402 - val_loss: 0.7122 - val_accuracy: 0.4974
# Epoch 20/50
# 118/118 [==============================] - 39s 334ms/step - loss: 0.7029 - accuracy: 0.5286 - val_loss: 0.7024 - val_accuracy: 0.5000
# Epoch 21/50
# 118/118 [==============================] - 39s 334ms/step - loss: 0.6857 - accuracy: 0.5470 - val_loss: 0.6930 - val_accuracy: 0.5105
# Epoch 22/50
# 118/118 [==============================] - 39s 330ms/step - loss: 0.6953 - accuracy: 0.5308 - val_loss: 0.6993 - val_accuracy: 0.5000
# Epoch 23/50
# 118/118 [==============================] - 39s 333ms/step - loss: 0.7033 - accuracy: 0.4937 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 24/50
# 118/118 [==============================] - 39s 335ms/step - loss: 0.6890 - accuracy: 0.5522 - val_loss: 0.6954 - val_accuracy: 0.5000
# Epoch 25/50
# 118/118 [==============================] - 39s 333ms/step - loss: 0.7008 - accuracy: 0.4899 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 26/50
# 118/118 [==============================] - 39s 331ms/step - loss: 0.6927 - accuracy: 0.5286 - val_loss: 0.7121 - val_accuracy: 0.5000
# Epoch 27/50
# 118/118 [==============================] - 39s 332ms/step - loss: 0.6889 - accuracy: 0.5348 - val_loss: 0.7013 - val_accuracy: 0.4974
# Epoch 28/50
# 118/118 [==============================] - 40s 342ms/step - loss: 0.6964 - accuracy: 0.5327 - val_loss: 0.6984 - val_accuracy: 0.5053
# Epoch 29/50
# 118/118 [==============================] - 42s 356ms/step - loss: 0.6984 - accuracy: 0.5321 - val_loss: 0.7030 - val_accuracy: 0.4974
# Epoch 30/50
# 118/118 [==============================] - 40s 339ms/step - loss: 0.6942 - accuracy: 0.5112 - val_loss: 0.6992 - val_accuracy: 0.4921
# Epoch 31/50
# 118/118 [==============================] - 40s 338ms/step - loss: 0.6916 - accuracy: 0.5486 - val_loss: 0.7165 - val_accuracy: 0.5053
# Epoch 32/50
# 118/118 [==============================] - 40s 342ms/step - loss: 0.7029 - accuracy: 0.5078 - val_loss: 0.7032 - val_accuracy: 0.5105
# Epoch 33/50
# 118/118 [==============================] - 42s 359ms/step - loss: 0.6941 - accuracy: 0.5331 - val_loss: 0.7106 - val_accuracy: 0.5053
# Epoch 34/50
# 118/118 [==============================] - 50s 421ms/step - loss: 0.6879 - accuracy: 0.5709 - val_loss: 0.7053 - val_accuracy: 0.5053
# Epoch 35/50
# 118/118 [==============================] - 48s 406ms/step - loss: 0.6977 - accuracy: 0.5268 - val_loss: 0.6932 - val_accuracy: 0.5026
# Epoch 36/50
# 118/118 [==============================] - 41s 344ms/step - loss: 0.6917 - accuracy: 0.5233 - val_loss: 0.6954 - val_accuracy: 0.5026
# Epoch 37/50
# 118/118 [==============================] - 43s 361ms/step - loss: 0.6929 - accuracy: 0.5252 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 38/50
# 118/118 [==============================] - 42s 353ms/step - loss: 0.6972 - accuracy: 0.5210 - val_loss: 0.7174 - val_accuracy: 0.4974
# Epoch 39/50
# 118/118 [==============================] - 44s 370ms/step - loss: 0.6968 - accuracy: 0.5307 - val_loss: 0.7009 - val_accuracy: 0.5000
# Epoch 40/50
# 118/118 [==============================] - 43s 367ms/step - loss: 0.6967 - accuracy: 0.5301 - val_loss: 0.7348 - val_accuracy: 0.4974
# Epoch 41/50
# 118/118 [==============================] - 42s 359ms/step - loss: 0.6957 - accuracy: 0.5508 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 42/50
# 118/118 [==============================] - 44s 373ms/step - loss: 0.6925 - accuracy: 0.5420 - val_loss: 0.7154 - val_accuracy: 0.5026
# Epoch 43/50
# 118/118 [==============================] - 43s 366ms/step - loss: 0.6876 - accuracy: 0.5550 - val_loss: 0.7044 - val_accuracy: 0.5053
# Epoch 44/50
# 118/118 [==============================] - 43s 364ms/step - loss: 0.6950 - accuracy: 0.5328 - val_loss: 0.7093 - val_accuracy: 0.4974
# Epoch 45/50
# 118/118 [==============================] - 41s 343ms/step - loss: 0.6840 - accuracy: 0.5554 - val_loss: 0.6940 - val_accuracy: 0.4921
# Epoch 46/50
# 118/118 [==============================] - 42s 352ms/step - loss: 0.6876 - accuracy: 0.5634 - val_loss: 0.6986 - val_accuracy: 0.5079
# Epoch 47/50
# 118/118 [==============================] - 48s 406ms/step - loss: 0.6883 - accuracy: 0.5453 - val_loss: 0.7067 - val_accuracy: 0.5053
# Epoch 48/50
# 118/118 [==============================] - 41s 352ms/step - loss: 0.6934 - accuracy: 0.5292 - val_loss: 0.7153 - val_accuracy: 0.5000
# Epoch 49/50
# 118/118 [==============================] - 40s 335ms/step - loss: 0.6910 - accuracy: 0.5562 - val_loss: 0.7012 - val_accuracy: 0.4974
# Epoch 50/50
# 118/118 [==============================] - 39s 330ms/step - loss: 0.6938 - accuracy: 0.5139 - val_loss: 0.7026 - val_accuracy: 0.4974

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
